# %% [markdown]
# # Setup
#
# You need to run this before start to adjust the setup.ini file.

# %%
import os

GENERICAL_PATH = "/".join(os.getcwd().split('/')[:-1])

# %% [markdown]
# # Simulation parameters
#
# Notebook objectives are below. Later on, move from this blueprint version to pure Python scripts.
#
# - create structure to define simulation input parameters
# - export to MATLAB/Octave format for MRST run

# %%
import platform, os, configparser
from datetime import datetime


def get_params(c: configparser) -> dict:   
    """
    Get simulation parameters from configuration setup file.
    
    Parameters
    ----------
        c : configparser
        
    Returns
    -------
    
        Dictionary of parameters.
    
    """ 
    
    # Read input parameters
    c.read(os.path.join('..','setup.ini'))

    # Sections
    sections = ['Paths', 'Pre-Processing', 'Grid', 'Fluid', 'Initial Conditions', 
                        'Boundary Conditions', 'Wells', 'Schedule', 'MATLAB']
    
    # Auxiliary function to reduce coding. 
    # Here, 'section=section' is used to bypass late binding and capture the looped value.
    # Otherwise, the 'section' value at lambda definition time would be the last looped value.
    aux = [lambda param, section=section: c.get(section, param) for section in sections]

    # TODO Remove globals and implement class. Should we transfer that to a Makefile??
    
    # check if the key Paths exists in the configuration file

    # Paths 
    global PUMLE_ROOT;      PUMLE_ROOT = c.get('Paths','PUMLE_ROOT') 
    global PUMLE_RESULTS;   PUMLE_RESULTS = c.get('Paths','PUMLE_RESULTS') 
    
    p_params = ['PUMLE_ROOT', 'PUMLE_RESULTS']    
        
    # Pre-Processing
    pp_params = ['case_name', 'file_basename', 'model_name']    
                                      
    # Grid
    gp_params = ['file_path', 'repair_flag']
    
    # Fluid
    fp_params = ['pres_ref', 'temp_ref', 'cp_rock', 'srw', 'src', 'pe', 'XNaCl', 'rho_h2o']

    # Initial Conditions
    sp_params = ['sw_0']

    # TODO Study MRST::addBC
    # Boundary conditions
    bc_params = ['type']

    # Well
    w_params = ['CO2_inj']

    # Schedule
    s_params = ['injection_time', 'migration_time', 'injection_timestep_rampup', 'migration_timestep']

    # MATLAB
    m_params = ['matlab','mrst_root']
    
    # Fetch sections to return a dict whose keys are sections and values are second-level dicts of parameters
    all_params = [p_params, pp_params, gp_params, fp_params, sp_params, bc_params, w_params, s_params, m_params]
    
    # Marks to do a type casting to float over numerical parameters.
    cast = [False, False, False, True, True, False, True, True, False]
    
    PARAMS = {}
    for k in range(len(all_params)):
        PARAMS[sections[k]] = dict(zip(all_params[k], [float(aux[k](_)) if cast[k] else aux[k](_) for _ in all_params[k]]))
        
    print(f'[PUMLE] Simulation setup file sucessfully read.')

    return PARAMS

def read_sim_params():
    """
    Read simulation parameters from the configuration file 'setup.ini'. 
    
    TODO Refactor this function to better define the top project folder and allow setup.ini to come from other path.

    Returns
    -------
    dict: 
    
    """
                    
    # Search in directory above
    if 'setup.ini' not in os.listdir('..'): 
        raise RuntimeError('File \'setup.ini\' not found in the top project folder. Change working directory and rerun this script.')
   
    else: 
        # Get path to top folder project inside 'setup.ini'                            
        c = configparser.ConfigParser()
        return get_params(c)
    
    

def dict_to_ini(config_dict):
    """Helper function to convert a dict back to .ini format"""
    
    ini_str = ""
    for section, items in config_dict.items():
        ini_str += f"[{section}]\n"
        for key, value in items.items():
            ini_str += f"{key} = {value}\n"
        ini_str += "\n"
    return ini_str



def print_report(PARAMS: dict, res_dir: str, msg: bool=True) -> None:
    """
    Print simulation setup report for log purposes.
    
    Parameters
    ---------
        PARAMS: dictionary of parameters
        res_dir: results output directory
        msg: log message
    
    """
    
    # Defaults results folder to '/temp'
    out = os.path.join(PUMLE_ROOT,res_dir)

    if len(res_dir) == 0:
        out = os.path.join(PUMLE_ROOT,'temp')
        os.makedirs(out,exist_ok=True)
    else:
        os.makedirs(out,exist_ok=True)
            
    # Get date/time and system information
    system, hostname, release, *_ =  platform.uname()
    date_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    # Text elements to write
    te = {
        0: ''.center(80,'-') + '\n',
        1: 'PUMLE SIMULATION REPORT'.center(80, ' ') + '\n',     
        2: f'Date/Time: {date_time}\n',   
        3: f'OS: {system}\n',
        4: f'Version: {release}\n',
        5: f'Hostname: {hostname}\n'
    }
    
    # Write report
    with open(os.path.join(PUMLE_ROOT,res_dir,'report.txt'),'w',) as fo:
        
        # Header
        fo.write(te[0])
        fo.write(te[1])
        fo.write(te[0])
                
        for k in range(2,6): fo.write(te[k])
        
        # Core information
        fo.write(te[0])        
        fo.write(dict_to_ini(PARAMS)) # TODO Should we change to another structure?        
    
    fo.close()
    
    if msg: print(f'[PUMLE] Report file saved to \'{out}\'.')
    

def export_to_matlab(PARAMS) -> None:
    """ Export dict of simulation parameters to Matlab to be read individually."""
    
    from scipy.io import savemat
    
    for k in PARAMS.keys():    
        basename = f'{k.replace('-','').replace(' ','')}ParamsPUMLE'
        mroot = os.path.join(PUMLE_ROOT,'m')
        fname = os.path.join(mroot,basename + '.mat')
        savemat(fname, PARAMS[k], appendmat=True)
        print(f'[PUMLE] Matlab file \'{basename + '.mat'}\' exported to \'{mroot}\'.')
        
        
def run_matlab_batch(PARAMS):    
    import subprocess
    
    # Path to Matlab binary in your computer
    bin = PARAMS['MATLAB']['matlab']
    
    mfile = PUMLE_ROOT + '/m'
    
    # Change directory to Matlab folder
    os.chdir(mfile)

    # Command to run matlab script in batch mode without Java
    cmd = f'-logfile co2lab3DPUMLE.log -nojvm -batch co2lab3DPUMLE'
    
    try:
        out = subprocess.run([bin] + cmd.split(), shell=False, check=True)
        print(f"[PUMLE] Calling Matlab in batch mode: {out.returncode}")
        
    except subprocess.CalledProcessError as e:
        print(f"[PUMLE] exception raise: {e}")
 
    # Change back to root folder
    os.chdir(os.path.join(PUMLE_ROOT,"ipynb"))
    
    
# ======== UTILITY

def reset_user(PARAMS):
    
    import re
    from termcolor import colored
    
    global PUMLE_ROOT; 
    
    if len(re.search('gustavo', PARAMS['Paths']['PUMLE_ROOT']).group()) > 0:
        PUMLE_ROOT = '/Users/gustavo/projects/pumle'
        PARAMS['Paths']['PUMLE_ROOT'] = PUMLE_ROOT
        PARAMS['Grid']['file_path'] = PUMLE_ROOT + '/benchmark/unisim-1-d/UNISIM_I_D_ECLIPSE.DATA'
        PARAMS['MATLAB']['matlab'] = '/Applications/MATLAB_R2024b.app/bin/matlab*'
        PARAMS['MATLAB']['mrst_root'] = '/Users/gustavo/projects/mrst-2024a'
        
        print(colored('[Warning] User was reset!', 'yellow', attrs=['bold']))
        
    return PARAMS
    


# ======== MAIN (KEEP THIS WAY FOR DEBUGGER REFERENCE)

def main():
    
    # Pipeline test
    PARAMS = read_sim_params()
    #PARAMS = reset_user(PARAMS) # <--- Only for prototyping
    print_report(PARAMS,PUMLE_RESULTS)
    export_to_matlab(PARAMS)
    run_matlab_batch(PARAMS)
    
if __name__ == "main":
    main()
    
main()
# Out:
# [PUMLE] Simulation setup file sucessfully read.
# [PUMLE] Report file saved to '/home/luiz/dev/tcc/PUMLE/sim'.
# [PUMLE] Matlab file 'PathsParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'PreProcessingParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'GridParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'FluidParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'InitialConditionsParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'BoundaryConditionsParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'WellsParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'ScheduleParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [PUMLE] Matlab file 'MATLABParamsPUMLE.mat' exported to '/home/luiz/dev/tcc/PUMLE/m'.
# [MATLAB] PUMLE's .mat files loaded for simulation.
# Welcome to the MATLAB Reservoir Simulation Toolbox (MRST)!
# You are using the release version 2024a. To download other versions of MRST
# and view examples and relevant publications, please visit www.mrst.no
#
# Useful commands for getting started:
#  - List all introductory examples:   mrstExamples()
#  - List all modules:                 mrstPath('list')
#  - Load modules using GUI:           mrstModule('gui')
#  - Explore all available data sets:  mrstDatasetGUI()
#  - List examples of a module:        mrstExamples('ad-blackoil')
#  - Explore modules and publications: mrstExploreModules()
#  - Show all examples in all modules: mrstExamples('all')
#  - Show settings for MRST:           mrstSettings()
#  - Display this message:             mrstStartupMessage()
#
# For assistance and discussions about MRST, please visit our mailing list at
# 	www.sintef.no/projectweb/mrst/forum/ (sintef-mrst@googlegroups.com)
# For some common queries, see our FAQ: www.sintef.no/projectweb/mrst/faq/
# Warning: Left-handed test is ill-posed. No way of verifying right-handed
# coordinate system
# > In processGRDECL>is_lefthanded (line 430)
# In processGRDECL>build_coordinates (line 392)
# In processGRDECL (line 204)
# In co2lab3DPUMLE (line 59)
# Warning: Colon operands must be real scalars. This warning will become an error
# in a future release.
# > In processGRDECL>computeFaceGeometry (line 1066)
# In processGRDECL>findFaults (line 892)
# In processGRDECL>process_pillar_faces (line 483)
# In processGRDECL (line 235)
# In co2lab3DPUMLE (line 59)
#
# Warning: Colon operands must be real scalars. This warning will become an error
# in a future release.
# > In processGRDECL>computeFaceGeometry (line 1066)
# In processGRDECL>findFaults (line 892)
# In processGRDECL>process_pillar_faces (line 483)
# In processGRDECL (line 245)
# In co2lab3DPUMLE (line 59)
#
# Solving timestep 01/20:          -> 4 Days, 13 Hours, 2061.90 Seconds
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.708159e-20.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.838933e-68.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is singular to working precision.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver failure after 6 iterations for timestep of length 4 Days, 13 Hours, 2061 Seconds, 900 Milliseconds. Cutting timestep.
# Failure reason: Linear solver failure: : Linear system rhs must have finite entries.
# Cutting timestep.
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  5.266981e-37.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is singular to working precision.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver failure after 5 iterations for timestep of length 2 Days, 6 Hours, 2830 Seconds, 950 Milliseconds. Cutting timestep.
# Failure reason: Linear solver produced non-finite values.
# Cutting timestep.
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.126142e-22.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.146516e-30.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND = 9.894282e-171.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver failure after 6 iterations for timestep of length 1 Day, 3 Hours, 1415 Seconds, 475 Milliseconds. Cutting timestep.
# Failure reason: Linear solver failure: : Linear system rhs must have finite entries.
# Cutting timestep.
# Solving timestep 02/20: 4 Days, 13 Hours, 2061.90 Seconds -> 9 Days, 3 Hours, 523.80 Seconds
# Solving timestep 03/20: 9 Days, 3 Hours, 523.80 Seconds -> 18 Days, 6 Hours, 1047.60 Seconds
# Solving timestep 04/20: 18 Days, 6 Hours, 1047.60 Seconds -> 36 Days, 12 Hours, 2095.20 Seconds
# Solving timestep 05/20: 36 Days, 12 Hours, 2095.20 Seconds -> 73 Days, 1 Hour, 590.40 Seconds
# Solver did not converge in 25 iterations for timestep of length 36 Days, 12 Hours, 2095 Seconds, 200 Milliseconds. Cutting timestep.
# Solving timestep 06/20: 73 Days, 1 Hour, 590.40 Seconds -> 146 Days, 2 Hours, 1180.80 Seconds
# Solving timestep 07/20: 146 Days, 2 Hours, 1180.80 Seconds -> 219 Days, 3 Hours, 1771.20 Seconds
# Solving timestep 08/20: 219 Days, 3 Hours, 1771.20 Seconds -> 292 Days, 4 Hours, 2361.60 Seconds
# Solving timestep 09/20: 292 Days, 4 Hours, 2361.60 Seconds -> 1 Year
# Solving timestep 10/20: 1 Year   -> 1 Year, 73 Days, 1.16 Hour
# Solving timestep 11/20: 1 Year, 73 Days, 1.16 Hour -> 1 Year, 146 Days, 2.33 Hours
# Solver did not converge in 25 iterations for timestep of length 73 Days, 1 Hour, 590 Seconds, 400 Milliseconds. Cutting timestep.
# Solving timestep 12/20: 1 Year, 146 Days, 2.33 Hours -> 1 Year, 219 Days, 3.49 Hours
# Solving timestep 13/20: 1 Year, 219 Days, 3.49 Hours -> 1 Year, 292 Days, 4.66 Hours
# Solving timestep 14/20: 1 Year, 292 Days, 4.66 Hours -> 1 Year, 365 Days, 5.82 Hours
# Solving timestep 15/20: 1 Year, 365 Days, 5.82 Hours -> 2 Years
# Solving timestep 16/20: 2 Years  -> 4 Years
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  2.069378e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.918590e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  8.036991e-18.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  3.441097e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  4.058523e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  6.315748e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  9.310106e-26.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver failure after 12 iterations for timestep of length 2 Years. Cutting timestep.
# Failure reason: Linear solver failure: : Linear system rhs must have finite entries.
# Cutting timestep.
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.322469e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  2.019386e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.866462e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  8.788653e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver did not converge in 25 iterations for timestep of length 1 Year. Cutting timestep.
# Solving timestep 17/20: 4 Years  -> 6 Years
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.398683e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  2.030589e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  6.007876e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  2.042072e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  2.119643e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.283059e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.464990e-16.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver did not converge in 25 iterations for timestep of length 2 Years. Cutting timestep.
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  1.815083e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  9.695929e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  8.309853e-17.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Warning: Matrix is close to singular or badly scaled. Results may be
# inaccurate. RCOND =  6.740316e-22.
# > In BackslashSolverAD/solveLinearSystem (line 21)
# In LinearSolverAD/solveLinearProblem (line 361)
# In PhysicalModel/stepFunction (line 739)
# In ReservoirModel/stepFunction (line 307)
# In NonLinearSolver/solveMinistep (line 374)
# In NonLinearSolver/solveTimestep (line 210)
# In simulateScheduleAD (line 295)
# In co2lab3DPUMLE (line 465)
#
# Solver failure after 23 iterations for timestep of length 1 Year. Cutting timestep.
# Failure reason: Linear solver failure: : Linear system rhs must have finite entries.
# Cutting timestep.
# Solver did not converge in 25 iterations for timestep of length 182 Days, 14 Hours, 3276 Seconds. Cutting timestep.
# Solving timestep 18/20: 6 Years  -> 8 Years
# Solving timestep 19/20: 8 Years  -> 10 Years
# Solving timestep 20/20: 10 Years -> 12 Years
# *** Simulation complete. Solved 20 control steps in 1 Hour, 2152 Seconds, 517 Milliseconds ***
# Error using save
# Unable to save file '/home/luiz/dev/tcc/PUMLE/sim/wellSols_GCS01.mat'. The file
# could not be closed, and might now be corrupt.
#
# Error in co2lab3DPUMLE (line 491)
# save(fullfile(PARAMS.Paths.PUMLE_ROOT,...
# [PUMLE] exception raise: Command '['/usr/local/MATLAB/R2024a/bin/matlab', '-logfile', 'co2lab3DPUMLE.log', '-nojvm', '-batch', 'co2lab3DPUMLE']' returned non-zero exit status 1.
